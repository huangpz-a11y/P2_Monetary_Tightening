# %%
#Imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
#Series 2 of RCFD, could've been any of the file


rcfd_data_2 = pd.read_csv(r'..\data\manual\dycfrwcdm9puanhs.csv') #series 2 of rcfd

# %%
#Asset Level

asset_level_0 = rcfd_data_2[['RSSD9001','RSSD9017','RSSD9999','RCFD2170']]
asset_level_0 = asset_level_0.fillna(0)
filtered_asset_level_0 = asset_level_0[asset_level_0['RSSD9999'] == '03/31/2022']
filtered_asset_level_0
# Out:
#        RSSD9001                          RSSD9017    RSSD9999  RCFD2170
# 0            37            BANK OF HANCOCK COUNTY  03/31/2022       0.0
# 5           242  FIRST COMMUNITY BANK XENIA-FLORA  03/31/2022       0.0
# 10          279       MINEOLA COMMUNITY BANK, SSB  03/31/2022       0.0
# 15          354                  BISON STATE BANK  03/31/2022       0.0
# 20          457                  LOWRY STATE BANK  03/31/2022       0.0
# ...         ...                               ...         ...       ...
# 23870   5620869                      GENESIS BANK  03/31/2022       0.0
# 23875   5650923                    WATERFALL BANK  03/31/2022       0.0
# 23880   5660146                         ENTREBANK  03/31/2022       0.0
# 23885   5673191                     LOCALITY BANK  03/31/2022       0.0
# 23894   5691319         SCOTTSDALE COMMUNITY BANK  03/31/2022       0.0
#
# [4844 rows x 4 columns]

# %%
#other_series that Jeremy provided with RSSD9010

other_data = pd.read_csv(r'..\data\manual\nw5crmbtaa03thi9.csv')

# %%
#I already queried the data to have the date March 31st 2022. 

#Variables: BHCT2170, BHSP2170, BHCP2170, BHCA2170 are all total assets from different times to current(I filled in NAs with 0)

#I combined all the total assets in order for all GSIB to have some value
other_data = other_data.fillna(0)
other_data['Total Asset'] = other_data['BHCT2170'] + other_data['BHSP2170'] + other_data['BHCP2170'] + other_data['BHCA2170']

# %%
other_df = other_data[['RSSD9001', 'RSSD9999', 'RSSD9017', 'RSSD9010', 'Total Asset']]
other_df
# Out:
#      RSSD9001    RSSD9999                                RSSD9017  \
# 0     1020180  2022-03-31            BREMER FINANCIAL CORPORATION
# 1     1020201  2022-03-31                           HSBC USA INC.
# 2     1020902  2022-03-31        FIRST NATIONAL OF NEBRASKA, INC.
# 3     1022764  2022-03-31         CENTRAL PACIFIC FINANCIAL CORP.
# 4     1023220  2022-03-31  B.N.Y. HOLDINGS (DELAWARE) CORPORATION
# ..        ...         ...                                     ...
# 427   5375459  2022-03-31           EB ACQUISITION COMPANY II LLC
# 428   5478903  2022-03-31                               CSBH, LLC
# 429   5530258  2022-03-31                 CARTER BANKSHARES, INC.
# 430   5559343  2022-03-31              AMALGAMATED FINANCIAL CORP
# 431   5586871  2022-03-31                 SOFI TECHNOLOGIES, INC.
#
#                   RSSD9010  Total Asset
# 0         BREMER FNCL CORP   17706989.0
# 1                 HSBC USA   34557478.0
# 2          FIRST NAT OF NE   30654054.0
# ...

# %%
#GSIB list with all different versions of each big bank(26 banks)

GSIB_list = ['JPMORGAN CHASE & CO', 'JPMORGAN CHASE HOLDS LLC', 'BANK OF AMER CORP', 'BANK OF NY MELLON CORP', 'CITIGROUP', 'CITICORP LLC',
'HSBC USA', 'HSBC N AMER HOLDS', 'BARCLAYS GROUP US', 'BARCLAYS US LLC', 'BNP PARIBAS USA', 'DEUTSCHE BK TR CORP', 'GOLDMAN SACHS GROUP THE', 'MUFG AMERS HOLDS CORP', 'UBS AMERS HOLD LLC', 'MIZUHO AMERS LLC', 'MORGAN STANLEY', 'MORGAN STANLEY DOMESTIC HOLD', 'MORGAN STANLEY CAP MGMT LLC', 'RBC USA HOLDCO CORP', 'RBC US GRP HOLDS LLC', 'SANTANDER HOLDS USA', 'STATE STREET CORP', 'WELLS FARGO & CO', 'TD GRP US HOLDS LLC', 'TD BK US HC']

# %%
GSIB_list
# Out:
# ['JPMORGAN CHASE & CO',
#  'JPMORGAN CHASE HOLDS LLC',
#  'BANK OF AMER CORP',
#  'BANK OF NY MELLON CORP',
#  'CITIGROUP',
#  'CITICORP LLC',
#  'HSBC USA',
#  'HSBC N AMER HOLDS',
#  'BARCLAYS GROUP US',
#  'BARCLAYS US LLC',
#  'BNP PARIBAS USA',
#  'DEUTSCHE BK TR CORP',
#  'GOLDMAN SACHS GROUP THE',
#  'MUFG AMERS HOLDS CORP',
#  'UBS AMERS HOLD LLC',
#  'MIZUHO AMERS LLC',
#  'MORGAN STANLEY',
#  'MORGAN STANLEY DOMESTIC HOLD',
#  'MORGAN STANLEY CAP MGMT LLC',
#  'RBC USA HOLDCO CORP',
#  'RBC US GRP HOLDS LLC',
#  'SANTANDER HOLDS USA',
#  'STATE STREET CORP',
#  'WELLS FARGO & CO',
#  'TD GRP US HOLDS LLC',
#  'TD BK US HC']

# %%
#Filtered df

df = pd.DataFrame(GSIB_list)

filtered_df = other_df[other_df['RSSD9010'].isin(GSIB_list)]
filtered_df
# Out:
#      RSSD9001    RSSD9999                                  RSSD9017  \
# 1     1020201  2022-03-31                             HSBC USA INC.
# 17    1032473  2022-03-31           DEUTSCHE BANK TRUST CORPORATION
# 19    1039502  2022-03-31                      JPMORGAN CHASE & CO.
# 51    1073757  2022-03-31               BANK OF AMERICA CORPORATION
# 90    1111435  2022-03-31                  STATE STREET CORPORATION
# 101   1120754  2022-03-31                     WELLS FARGO & COMPANY
# 173   1249196  2022-03-31                TD BANK US HOLDING COMPANY
# 178   1378434  2022-03-31        MUFG AMERICAS HOLDINGS CORPORATION
# 200   1575569  2022-03-31                     BNP PARIBAS USA, INC.
# 211   1951350  2022-03-31                            CITIGROUP INC.
# 231   2162966  2022-03-31                            MORGAN STANLEY
# 248   2380443  2022-03-31            GOLDMAN SACHS GROUP, INC., THE
# 290   2914521  2022-03-31                    BARCLAYS GROUP US INC.
# ...

# %%
#Add the banks from the RCFD that aren't in filtered_df

x = [925411, 1015560, 655839]

RCFD_GSIB = filtered_asset_level_0[['RSSD9001', 'RSSD9999', 'RSSD9017', 'RCFD2170']]
R_gsib = RCFD_GSIB[RCFD_GSIB['RSSD9001'].isin(x)]
R_gsib.rename(columns={'RCFD2170': 'Total Asset'}, inplace=True)
R_gsib
# Out:
#        RSSD9001    RSSD9999  \
# 12367    655839  03/31/2022
# 17688    925411  03/31/2022
# 19537   1015560  03/31/2022
#
#                                                 RSSD9017  Total Asset
# 12367                                 CCB COMMUNITY BANK          0.0
# 17688        SUMITOMO MITSUI TRUST BANK (U.S.A.) LIMITED          0.0
# 19537  INDUSTRIAL AND COMMERCIAL BANK OF CHINA (USA),...          0.0

# %%
#29 banks using other_series as main source of GSIB banks(RSSD9001 don't match together with RCFD)

#filtered_df.drop(columns=['RSSD9010'], inplace=True)
stacked_df = pd.concat([filtered_df, R_gsib], ignore_index=True)
stacked_df
# Out:
#     RSSD9001    RSSD9999                                           RSSD9017  \
# 0    1020201  2022-03-31                                      HSBC USA INC.
# 1    1032473  2022-03-31                    DEUTSCHE BANK TRUST CORPORATION
# 2    1039502  2022-03-31                               JPMORGAN CHASE & CO.
# 3    1073757  2022-03-31                        BANK OF AMERICA CORPORATION
# 4    1111435  2022-03-31                           STATE STREET CORPORATION
# 5    1120754  2022-03-31                              WELLS FARGO & COMPANY
# 6    1249196  2022-03-31                         TD BANK US HOLDING COMPANY
# 7    1378434  2022-03-31                 MUFG AMERICAS HOLDINGS CORPORATION
# 8    1575569  2022-03-31                              BNP PARIBAS USA, INC.
# 9    1951350  2022-03-31                                     CITIGROUP INC.
# 10   2162966  2022-03-31                                     MORGAN STANLEY
# ...

# %%
#Combined Total Assets(Seems kind of high)

stacked_df['Total Asset'].sum()
# Out:
# 21043580255.0

# %%
#In comparison to all exisiting GSIB banks in RCFD already(37)

bank_numbers = [
    651448, 852218, 480228, 1443266, 476810, 413208, 3357620, 1015560, 2980209,
    214807, 304913, 670560, 2325882, 3066025, 2182786, 3212149, 541101, 934329,
    398668, 488318, 229913, 1456501, 2489805, 3783948, 722777, 35301, 812164,
    93619, 352745, 925411, 497404, 2121196, 2362458, 2531991, 451965, 688079,
    1225761
]

filtered_asset_level_0
Rcfd_gsib = filtered_asset_level_0[filtered_asset_level_0['RSSD9001'].isin(bank_numbers)]
Rcfd_gsib
# Out:
#        RSSD9001                                           RSSD9017  \
# 635       35301                STATE STREET BANK AND TRUST COMPANY
# 1736      93619  STATE STREET BANK AND TRUST COMPANY, NATIONAL ...
# 3918     214807               DEUTSCHE BANK TRUST COMPANY AMERICAS
# 4163     229913                                  MIZUHO BANK (USA)
# 5696     304913               DEUTSCHE BANK TRUST COMPANY DELAWARE
# 6547     352745                STATE STREET BANK AND TRUST COMPANY
# 7441     398668  BANK OF NEW YORK MELLON TRUST COMPANY, NATIONA...
# 7740     413208                HSBC BANK USA, NATIONAL ASSOCIATION
# 8441     451965             WELLS FARGO BANK, NATIONAL ASSOCIATION
# 8949     476810                                     CITIBANK, N.A.
# 9047     480228              BANK OF AMERICA, NATIONAL ASSOCIATION
# 9201     488318                       BNY MELLON TRUST OF DELAWARE
# 9356     497404                                      TD BANK, N.A.
# ...

# %%
#Cut all the banks that have RCFD2170 of 0, you are left with 25 banks

Rcfd_gsib = Rcfd_gsib[Rcfd_gsib['RCFD2170'] != 0]
Rcfd_gsib['RSSD9001'].tolist()
# Out:
# [35301,
#  93619,
#  229913,
#  398668,
#  413208,
#  451965,
#  476810,
#  480228,
#  488318,
#  497404,
#  541101,
#  651448,
#  688079,
#  722777,
#  812164,
#  852218,
#  934329,
#  1225761,
#  1443266,
#  1456501,
#  2182786,
#  2362458,
#  2489805,
#  2531991,
#  3066025]

# %%
#Total Assets of 25 banks

Rcfd_gsib['RCFD2170'].sum()
# Out:
# 11842332171.0

# %% [markdown]
# The original RCFD data had these banks(I checked multiple times:)
#
# Banks and their RSSD9001:
#
# JPMorgan Chase - 651448
# JPMORGAN CHASE BANK, NATIONAL ASSOCIATION - 852218
# Bank of America, National Association - 480228
# BANK OF AMERICA CALIFORNIA, NATIONAL ASSOCIATION - 1443266
# CITIBANK, N.A. - 476810
# HSBC BANK USA, NATIONAL ASSOCIATION - 413208
# HSBC TRUST COMPANY (DELAWARE), NATIONAL ASSOCIATION - 3357620
# INDUSTRIAL AND COMMERCIAL BANK OF CHINA (USA), NATIONAL ASSOCIATION - 1015560
# BARCLAYS BANK DELAWARE - 2980209
#
#
# No Bank of China, Agricultural Bank of China, BNP Paribas, China Construction Bank, No bank of communication, Groupe BPCE, Groupe Crédit Agricole, ING, Société Générale, Standard Chartered,
#
# DEUTSCHE BANK TRUST COMPANY AMERICAS - 214807
# DEUTSCHE BANK TRUST COMPANY DELAWARE - 304913
# DEUTSCHE BANK NATIONAL TRUST COMPANY - 670560
# DEUTSCHE BANK TRUST COMPANY, NATIONAL ASSOCIATION - 2325882
# GOLDMAN SACHS TRUST COMPANY, NATIONAL ASSOCIATION, THE - 3066025
# GOLDMAN SACHS BANK USA - 2182786
# UBS BANK USA - 3212149
# BANK OF NEW YORK MELLON, THE - 541101
# BNY MELLON, NATIONAL ASSOCIATION - 934329
# BANK OF NEW YORK MELLON TRUST COMPANY, NATIONAL ASSOCIATION, THE - 398668
# BNY MELLON TRUST OF DELAWARE - 488318
# MIZUHO BANK (USA) - 229913
# MORGAN STANLEY BANK, N.A. - 1456501
# MORGAN STANLEY PRIVATE BANK, NATIONAL ASSOCIATION - 2489805
# RBC BANK (GEORGIA), NATIONAL ASSOCIATION - 3783948
# SANTANDER BANK, NATIONAL ASSOCIATION - 722777
# STATE STREET BANK AND TRUST COMPANY - 35301
# STATE STREET BANK AND TRUST COMPANY OF CALIFORNIA, NATIONAL ASSOCIATION - 812164
# STATE STREET BANK AND TRUST COMPANY, NATIONAL ASSOCIATION - 93619
# STATE STREET BANK AND TRUST COMPANY - 352745
# SUMITOMO MITSUI TRUST BANK (U.S.A.) LIMITED - 925411
# TD BANK, N.A. - 497404
# TD BANK USA, NATIONAL ASSOCIATION - 2121196
# WELLS FARGO BANK SOUTH CENTRAL, NATIONAL ASSOCIATION - 2362458
# WELLS FARGO DELAWARE TRUST COMPANY, NATIONAL ASSOCIATION - 2531991
# WELLS FARGO BANK, NATIONAL ASSOCIATION - 451965
# WELLS FARGO TRUST COMPANY, NATIONAL ASSOCIATION - 688079
# WELLS FARGO NATIONAL BANK WEST - 1225761

# %% [markdown]
# Other Series
#
# Contains BNP Paribas, and Barclays Group instead of specifically Barclays Delaware. In addition to RBC US and USA instead of RBC Georgia and other exampes like HSBC USA instead of HSBC Delaware. Could be maybe helpful cause these have asset values instead of 0s.
